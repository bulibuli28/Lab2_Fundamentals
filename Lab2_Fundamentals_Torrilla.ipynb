# %%
ENGINEER = "Torrilla"
STUDENT_ID = "TUPM-25-0921"

SEED_NUM = int(STUDENT_ID[-1])

print(f"System Initialized for: {ENGINEER}")
print(f"Algorithmic Seed Value: {SEED_NUM}")
# Out:
# System Initialized for: Torrilla
# Algorithmic Seed Value: 1

# %%
actual = 0.1 + 0.2
print(f"Python stores: {actual}")

if actual == 0.3:
    print("Result: Perfect Match")
else:
    print("Result: PRECISION ERROR (Binary Artifact)")
# Out:
# Python stores: 0.30000000000000004
# Result: PRECISION ERROR (Binary Artifact)

# %%
first_letter = ENGINEER[0]
byte_val = ord(first_letter)

print(f"Character: {first_letter}")
print(f"ASCII Value: {byte_val}")
print(f"Next in Sequence: {chr(byte_val + 1)}")
# Out:
# Character: T
# ASCII Value: 84
# Next in Sequence: U

# %%
raw_in = input("Enter Name(Matthew B. Torrilla): ")
clean_in = raw_in.strip().upper()
print(f"Original: '{raw_in} | Cleaned: '{clean_in}'")
# Out:
# Original: 'm a t t h e w | Cleaned: 'M A T T H E W'

# %%
user_input =("Press Enter (leave empty) or type data: ")
if user_input:
    print(f"Data Detected: {user_input}")
else:
    print("ALERT: No data stream detected.")
# Out:
# Data Detected: Press Enter (leave empty) or type data:

# %%
campus = STUDENT_ID[0:4]
unique_id = STUDENT_ID[8:]

tokens = STUDENT_ID.split("-")
print(f"Campus Code: {campus}")
print(f"Unique Sequence: {unique_id}")
print(f"Token List: {tokens}")
# Out:
# Campus Code: TUPM
# Unique Sequence: 0921
# Token List: ['TUPM', '25', '0921']

# %%
if SEED_NUM % 2 == 0:
    priority = "LOW (Even Seed)"
else:
    priority = "HIGH (Odd Seed)"
print(f"System Priority: {priority}")
# Out:
# System Priority: HIGH (Odd Seed)

# %%
limit = (SEED_NUM * 10) + 20
print(f"--- SAFETY LIMIT: {limit} ---")
val = int(input("Enter Sensor Reading: "))

if val > limit:
    print("ALERT: Over Limit")
elif val < 5:
    print("ALERT: Low Signal")
else: 
    print("STATUS: Nominal")
# Out:
# --- SAFETY LIMIT: 30 ---
# ALERT: Over Limit

# %%
try:
    voltage = int(input("Enter Voltage (Numeric): "))
    print(f"Voltage Captured: {voltage}V")
except ValueError:
    print("SYSTEM ERROR: Input must be numeric. Resetting to 0.")
    voltage = 0
print(f"System continues... Current Voltage: {voltage}")
# Out:
# SYSTEM ERROR: Input must be numeric. Resetting to 0.
# System continues... Current Voltage: 0

# %%
has_power = False
if has_power and (10 / 0 == 0):
    print("System On")
else: 
    print("System Off (SHort-Circuit Triggered)")
# Out:
# System Off (SHort-Circuit Triggered)

# %%
loops = SEED_NUM + 3
print(f"--- RUNNING {loops} CYCLES ---")

for i in range(1, loops + 1):
    print(f"Cycle {i}/{loops} ... Complete")
# Out:
# --- RUNNING 4 CYCLES ---
# Cycle 1/4 ... Complete
# Cycle 2/4 ... Complete
# Cycle 3/4 ... Complete
# Cycle 4/4 ... Complete

# %%
rows = int(tokens[2][2])
cols = int(tokens[2][2])
print(f"Generating {rows}x{cols} Matrix:")
for r in range(rows):
    for c in range(cols):
        print("#", end=" ")
    print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 rows = int(tokens[2][2])
#       2 cols = int(tokens[2][2])
#       3 print(f"Generating {rows}x{cols} Matrix:")
#
# NameError: name 'tokens' is not defined

# %%
while True:
    pwd = input("Type 'ADMIN' to exit: ")
    if pwd == "ADMIN":
        print("Unlocked.")
        break
    else:
        print("Access Denied.")
# Out:
# Unlocked.

# %%
A = byte_val
B = SEED_NUM
C = loops

verification_hash = (A * B) - C

print(f"User: {ENGINEER}")
print(f"Forensic Signature: {verification_hash}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 A = byte_val
#       2 B = SEED_NUM
#       3 C = loops
#
# NameError: name 'byte_val' is not defined

# %%
target_name = "TORRILLA"  
SEED_NUM = 1            
redacted_name = ""

# %%
ENGINEER = "MATTHEW"     
SEED_NUM = 1        
total_loops = 4     

first_letter_ascii = ord(ENGINEER[0])

verification_hash = (first_letter_ascii * SEED_NUM) - total_loops

print("First Letter ASCII:", first_letter_ascii)
print("SEED_NUM:", SEED_NUM)
print("Total Loops:", total_loops)
print("Verification Hash:", verification_hash)
# Out:
# First Letter ASCII: 77
# SEED_NUM: 1
# Total Loops: 4
# Verification Hash: 73

# %%
correct_password = "677667"   
attempts = 0                

while True:
    user_input = input("Enter password: ")
    attempts += 1
    if user_input == correct_password:
        print("Access Granted!")
        break
    else:
        print("Access Denied.")
# Out:
# Access Granted!
